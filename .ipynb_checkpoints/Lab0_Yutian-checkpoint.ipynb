# %% [markdown]
# ### Lab 0 Yutian He
#
# 1) Github homepage
#
# ![githubHomepage.png](attachment:687f0e4e-ffcb-49f3-b598-a0f8a9f199da.png)

# %% [markdown]
# 2) Git/learngitbybranchin
#
# ![gitstudy.png](attachment:d35b5f14-d4f8-4564-a6a9-1db85366f635.png)
#
# This is a good learning process. Each step is very clear, and the examples are easy to understand. It is relatively simple to run a single command. When performing multiple steps, I need to know how to do each step and truly understand the relationship between different commands. During the study, I found that git can track the change for a project, it can help us with bug identification, and change reverting. For the version control, it offers a detailed history of changes, good for us to check our previous work.
